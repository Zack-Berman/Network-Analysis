# %% [markdown]
# ## Data Set Information
#
# The files in this directory include:
#
# regInterFullFiltered.html - A listing of all the interactions in the data in an HTML table.
#
# coliInterFullVec.txt - All interactions in the dataset listed as a three column vector (operon number, transcription factor number, regulation type (1 activator, 2 repressor, 3 dual)).
#
# coliInterNoAutoRegVec.txt - A binary (unsigned) version of coliInterFullVec only without autoregulation interactions.
#
# coliInterFullNames.txt - A two column vector, the first column is a number, matching the number of the first two columns of the above interaction files, and the second column is the name of the operon.
#
# RegulonDB data is of version 3.2 XML version with the unknown interactions, and the chip only interactions (00001) NOT included.
# All other data collected by Shai Shen-Orr under the supervision of Dr. Uri Alon
#
# There are 578 interactions in the matrix (519 with no autoregulation).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import scipy.stats as stats
import sklearn
from IPython.display import Image
# %matplotlib inline

# %%
display(Image('operon_med.jpg'))

# %% [markdown]
# ## Background Information
#
# In bacteria, genes are rarely expressed (transcribed into proteins) on their own. Often, genes are expressed together, and groups of genes that are controlled together are known as **operons**. An operon's expression can be increased (output of proteins goes up) or decreased by proteins known as **transcription factors**. Transcription factors (TFs) will bind to a section of DNA just before the start of an operon and either increase or decrease the expression levels of that operon.
#
# Activators are TFs that only increase expression levels.
# Repressors are TFs that only decrease expression levels.
# There are TFs that can perform both functions, and those are known as dual TFs.
#
# Operons rarely function on their own. Transcriptional regulation networks are how operons interact with one other and orchestrate gene expression for the cell. These interconnected networks allow for changes in the expression of multiple operons from a single expression change specific central operons.
#
# We have several key questions regarding this E.coli network:
#
# 1. Are most of the genes in the network interconnected or separate?
# 2. Which genes are the most central to the network?
# 3. How does the distribution of TF classes play out in E. coli?

# %%
#import table with names of genes
names = pd.read_table('colinet/coliInterFullNames.txt', sep=' ', header=None)
names.columns = ['id', 'gene']

#import table containing all interactions
full_vec = pd.read_table('colinet/coliInterFullVec.txt', sep=' ', header=None)
full_vec.columns = ['operon_number', 'transcription_number', 'regulation_type']
full_vec['regulation_type'] = full_vec['regulation_type'].replace([1, 2, 3], ['activator', 'repressor', 'dual'])

#import names of operons and transcrption factors
operons = pd.read_csv('colinet/operon_names.csv')
operons.columns = ['transcripion_name', 'operon_name']
names = names.join(operons)

#merge the two tables on the indexes
df = names.merge(full_vec, left_index=True, right_index=True)

print(df.shape)
df.head()
# Out:
# (423, 7)
#    id    gene transcripion_name operon_name  operon_number  \
# 0   1  aceBAK              AcrR       acrAB              3
# 1   2    acnA               Ada    ada-alkB              6
# 2   3   acrAB               Ada        aidB             11
# 3   4    acrR               Ada        alkA             14
# 4   5     acs              AdiY        adiA              8
#
#    transcription_number regulation_type
# 0                     4       repressor
# 1                     6            dual
# 2                     6       activator
# 3                     6       activator
# 4                     9       activator

# %%
#print the number of unique variables in each feature
for col in df:
    print('Unique '+ col + ' variables:', df[col].nunique())
# Out:
# Unique id variables: 423
# Unique gene variables: 423
# Unique transcripion_name variables: 88
# Unique operon_name variables: 280
# Unique operon_number variables: 272
# Unique transcription_number variables: 87
# Unique regulation_type variables: 3

# %%
#create a list of tuples between the operon and transcription numbers
tuples = [(x[4], x[5]) for x in df.values]

#create a blank network graph
G = nx.Graph()

#fill the network graph with the tuple list as edges
G.add_edges_from(tuples)

# %%
#add attributes to the nodes in the graph
for node in df['id']:
    if node in G.nodes():
        G.node[node]['Gene'] = df.loc[df['id']==node,'gene'].values[0]
        G.node[node]['Regulation Type'] = df.loc[df['id']==node,'regulation_type'].values[0]
        G.node[node]['Transcription Factor Name'] = df.loc[df['id']==node,'transcripion_name'].values[0]
        G.node[node]['Operon Name'] = df.loc[df['id']==node,'operon_name'].values[0]

#view the attributes of node 10        
print('Node 10: ', G.nodes[10])
# Out:
# Node 10:  {'Gene': 'ahpCF', 'Regulation Type': 'dual', 'Transcription Factor Name': 'AraC', 'Operon Name': 'araE'}

# %% [markdown]
# ## Network Graph - "Rough Graph"
#
# In this network map, the nodes are operons and the edges are the trancription factors. An initial visual inspection of the graph shows a large central node with a number of small outlying nodes. A statistical analysis of the network will be done to confirm this. There appears to be one highly central node, which will be worth investigating further.
#
# One key improvement that could be made to this graph is being able to uniquly identify the different types of TFs. This will be added in a second version of the graph later.

# %%
#draw the complete network graph
plt.figure(figsize=(15, 12))
nx.draw_networkx(G,
                 pos=nx.spring_layout(G), 
                 node_color='blue',
                 edge_color='black',
                 node_size=75,
                 with_labels=False,
                 alpha=.7
                 )
plt.title('E. Coli Operon-Transcription Factor Network')
plt.axis('off')
plt.show()

# %%
#gather network statistics and print a few
number_of_nodes = G.number_of_nodes()
number_of_edges = G.number_of_edges()
node_dict = dict(G.degree())
node_degrees = list(node_dict.values())
avg_degree = np.mean(node_degrees)
med_degree = np.median(node_degrees)
max_degree = max(node_degrees)
clustering = list(nx.clustering(G).values())
betweenness_cent = list(nx.betweenness_centrality(G).values())
component_sizes = [len(c) for c in sorted(nx.connected_components(G), key=len, reverse=True)]

print("This graph has {} nodes and {} edges.".format(number_of_nodes, number_of_edges))
print("The median degree is {} and the mean degree is {}.".format(med_degree, avg_degree))
print("A disease node with median degree is connected to {}% of other operons.".format((med_degree/number_of_nodes)*100))
print("The disease node with the maximum degree is connected to {}% of other operons.".format((max_degree/number_of_nodes)*100))
print("There are {} connected components within the graph.".format(nx.number_connected_components(G)))
# Out:
# This graph has 309 nodes and 423 edges.
# The median degree is 1.0 and the mean degree is 2.737864077669903.
# A disease node with median degree is connected to 0.3236245954692557% of other operons.
# The disease node with the maximum degree is connected to 23.948220064724918% of other operons.
# There are 31 connected components within the graph.

# %%
#print the node attributes for nodes with a degree greater than 10
for degree in G.degree():
    if degree[1] >= 10:
        print('Node '+ str(degree[0])+' with a degree of ' + str(degree[1]) + ':')
        print('\t', G.node[degree[0]])
# Out:
# Node 24 with a degree of 21:
# 	 {'Gene': 'arcA', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'glcDEFGB'}
# Node 64 with a degree of 12:
# 	 {'Gene': 'cpxAR', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'acs'}
# Node 66 with a degree of 74:
# 	 {'Gene': 'crp', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'ansB'}
# Node 136 with a degree of 10:
# 	 {'Gene': 'flhDC', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'yiaKLMNOPQRS'}
# Node 154 with a degree of 12:
# 	 {'Gene': 'fur', 'Regulation Type': 'dual', 'Transcription Factor Name': 'CytR', 'Operon Name': 'tsx'}
# Node 193 with a degree of 10:
# 	 {'Gene': 'hns', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FIS', 'Operon Name': 'leuX'}
# Node 137 with a degree of 16:
# 	 {'Gene': 'fliAZY', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CsgD', 'Operon Name': 'csgBA'}
# Node 143 with a degree of 24:
# 	 {'Gene': 'fnr', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'CysB', 'Operon Name': 'cysB'}
# Node 190 with a degree of 23:
# 	 {'Gene': 'himA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FIS', 'Operon Name': 'argX-hisR-leuT-proM'}
# Node 222 with a degree of 13:
# 	 {'Gene': 'lexA_dinF', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FliA', 'Operon Name': 'flhBAE'}
# Node 227 with a degree of 16:
# 	 {'Gene': 'lrp', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FliA', 'Operon Name': 'fliFGHIJK'}
# Node 274 with a degree of 13:
# 	 {'Gene': 'narL', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'GalR', 'Operon Name': 'galETKM'}
# Node 282 with a degree of 14:
# 	 {'Gene': 'nlpD_rpoS', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'GlcC', 'Operon Name': 'glcDEFGB'}

# %% [markdown]
# ## Cursory Analysis
#
# The nodes with the highest degrees have transcription factors and genes associated with the most vital aspects of cellular life. ArcA, CRP, CysB, GalR, and GlcC all play critical roles in cellular metabolism. CytR controls the transportation of nucleic material (material that makes up DNA and RNA) through the cell. FIS produces a precursor protein which makes transcription factors, which control gene expression. FliA produces the proteins that give E.coli the ability to move. CsgD produces bio-film, a substance that helps E.coli bind together and protects E.coli in harsher environments.
#
# CRP produces a molecule known as cAMP, the building block of ATP which is what E.coli uses to power the majority of intracellular functions. Nearly everything in the bacteria utilizes cAMP in one way or another.

# %%
#display network statistics as histograms to view distributions
plt.figure(figsize=(15, 10))

plt.subplot(221)
plt.hist(node_degrees)
plt.title('Degrees')

plt.subplot(222)
plt.hist(clustering)
plt.title('Clustering')

plt.subplot(223)
plt.hist(betweenness_cent)
plt.title('Betweenness')

plt.subplot(224)
plt.hist(component_sizes)
plt.title('Connected components')
plt.show()

# %% [markdown]
# ## Statistical Analysis
#
# As you can see, the majority of our nodes are not connected to many other nodes, with a massive outlier at 74. The majority of our nodes are not culusterd together, with one expection. It appears as though our nodes are either very sparsly connected, or highly clustered. There is little in between. We confirm what we visually saw above, that there is one, highly interconnected node.
#
# We can add all of this statistical infomration into its own data frame for further analysis.

# %%
#pull our node-level statistics together into a dataframe
graph_stats = pd.DataFrame({'node':list(dict(G.degree()).keys()),
                          'degree':list(dict(G.degree()).values()),
                          'clustering':list(nx.clustering(G).values()),
                          'betweenness_cent':list(nx.betweenness_centrality(G).values()),
                          'degree_cent':list(nx.degree_centrality(G).values())
                         })

#assign each node to a component by number
graph_stats['component'] = None
graph_stats['regulation_type'] = df['regulation_type']

#sort the components by size so that the largest component will be numbered 0
components = sorted(nx.connected_components(G), key=len, reverse=True)
for i,component in enumerate(components):
    graph_stats.loc[graph_stats['node'].isin(list(component)),'component']=i
    
graph_stats.head()
# Out:
#    node  degree  clustering  betweenness_cent  degree_cent  component  \
# 0     3       1         0.0          0.000000     0.003247          9
# 1     4       1         0.0          0.000000     0.003247          9
# 2     6       4         0.0          0.004738     0.012987          0
# 3    11       1         0.0          0.000000     0.003247          0
# 4    14       2         0.0          0.009434     0.006494          0
#
#   regulation_type
# 0       repressor
# 1            dual
# 2       activator
# 3       activator
# 4       activator

# %%
#log the betweenness centrality and degree for easier relationship viewing
graph_stats['log_between']=np.log(graph_stats['betweenness_cent']+.001)
graph_stats['log_degree']=np.log(graph_stats['degree']+1)

g = sns.pairplot(graph_stats,
                 vars=['log_between','clustering','log_degree'],
                 kind='scatter',
                plot_kws={'alpha':.3})
plt.show()

# %% [markdown]
# ## Continued Analysis
#
# The relationship between degree, clustering, and betweenness centrality all confirm that there is a core cluster of major players and then sparesly connected networks.
#
# Thus far, we have looked at the network graph as a whole. We can further check to see if any differences exist between the classes of regulators.

# %%
#plot the distribution of network statistics by the regulator type
plt.figure(figsize=(15, 7))

plt.subplot(211)
sns.countplot(y='regulation_type', data=graph_stats, orient='h', palette='cool_r')
plt.ylabel('Regulator Type')
plt.xlabel('Count')
plt.title('Types of Regulators')

plt.subplot(212)
sns.swarmplot(x='degree', y='regulation_type', data=graph_stats, palette='cool_r')
plt.xlabel('Number of Degrees')
plt.ylabel('Regulator Type')
plt.title('Degree by Class')

plt.tight_layout()
plt.show()

# %%
#continue plotting the distribution of network statistics by the regulator type
plt.figure(figsize=(15, 7))

plt.subplot(211)
sns.swarmplot(x='betweenness_cent', y='regulation_type', data=graph_stats, palette='cool_r')
plt.xlabel('Betweenness Centrality')
plt.ylabel('Regulator Type')
plt.title('Betweenness Centrality by Class')

plt.subplot(212)
sns.swarmplot(x='clustering', y='regulation_type', data=graph_stats, palette='cool_r')
plt.xlabel('Clustering')
plt.ylabel('Regulator Type')
plt.title('Clustering by Class')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis By Class
#
# The activator class of TFs are the most common class, making up just over 50% of all TFs. Dual function TFs are the minority
# class, comprising around 8% of TFs. The degree distributions between classes look similar for each class, with the exception the large central node being an activator class. Activator TFs have the 3 highest levels of degree, suggesting that activators are more connected on average than the other classes. We see an identical patter with betweeness centrality as we do with degree. There appears to be 3 classes of cluster, spare, moderate, and tightly clustered. Distrubtions are similar between the 3 classes.
#
# The differences between the means of our class statistics are not statistically significant to a p-value of 0.05 on any metric. This was confirmed by ANOVA and t-tests between classes, as seen below. However, these are not the optimal statistics used to analyze a network graph such as this.
#
# To measure how well a network is divided into clusters, we can look at **modularity**. Modularity was designed to measure how well a network can be divided in to clusters (modules). Networks with high modularity have dense connections between nodes. A Girvan-Newman algorithm is used to detect communities in networks by progressively removing edges from the network and analyzing the remaining communities. The modularity for this network is 40.6%, also showing that our network is not highly and densely clustered. A deeper dive into this network could isolate individual communities and clusters for further analysis.

# %%
#calculate network statistics for each regulator type and put into a new dataframe
component_df = pd.DataFrame()
component_df['number_nodes'] = graph_stats.groupby('regulation_type')['component'].count()
component_df['connections'] = graph_stats.groupby('regulation_type')['component'].apply(lambda x: len(set(x)))
component_df['connections_normed'] = component_df.connections/component_df.number_nodes
component_df['median_degree'] = graph_stats.groupby('regulation_type')['degree'].median()
component_df['avg_degree'] = graph_stats.groupby('regulation_type')['degree'].mean()
#component_df['count_clusters'] = graph_stats.groupby('regulation_type')['clustering'].count()
component_df['avg_clusters'] = graph_stats.groupby('regulation_type')['clustering'].mean()
#component_df['avg_centrality'] = graph_stats.groupby('betweenness_cent')['clustering'].mean()
component_df
# Out:
#                  number_nodes  connections  connections_normed  median_degree  \
# regulation_type
# activator                 166           19            0.114458            2.0
# dual                       24            6            0.250000            1.5
# repressor                 119           20            0.168067            1.0
#
#                  avg_degree  avg_clusters
# regulation_type
# activator          3.072289      0.120564
# dual               2.500000      0.152778
# repressor          2.319328      0.074344

# %%
#create a data frame of stats for each TF class
activators = graph_stats[graph_stats['regulation_type']=='activator']
repressors = graph_stats[graph_stats['regulation_type']=='repressor']
duals = graph_stats[graph_stats['regulation_type']=='dual']

#check for statistical significance
print('Clustering ANOVA:', stats.f_oneway(activators.clustering, repressors.clustering, duals.clustering))
print('Degree ANOVA:', stats.f_oneway(activators.degree, repressors.degree, duals.degree))
# Out:
# Clustering ANOVA: F_onewayResult(statistic=1.2383937064008246, pvalue=0.2912979184842806)
# Degree ANOVA: F_onewayResult(statistic=0.7799981662064372, pvalue=0.45931608302379046)

# %%
from networkx.algorithms import community
import itertools

community_generator = community.girvan_newman(G)
top_level_communities = next(community_generator)
next_level_communities = next(community_generator)

print('Coverage:', community.coverage(G, next_level_communities))
print('Performance:', community.performance(G, next_level_communities))
print('Modularity:', community.modularity(G, top_level_communities))
# Out:
# Coverage: 0.9858156028368794
# Performance: 0.5980120203421174
# Modularity: 0.4060912428951893

# %% [markdown]
# ## Network Map - Complete
#
# Now that the majority of the statistical analysis has been  completed, a more complete network map can be created. Each class of TF will be color coded.

# %%
#create a list of the regulation type attribute for each node
classlist=list(nx.get_node_attributes(G,'Regulation Type').values())

#set a legend for use in labeling
legend_dictionary={'activator': 0, 'repressor': 1, 'dual': 2}

#create a list that matches the value to the key in the legend
class_list = []
for stuff in classlist:
    for value in legend_dictionary.items():
        if stuff == value[0]:
            class_list.append(value[1])

#build a dictionary of node attributes that matches the legend dictionary
class_dict = dict(zip(list(G.nodes), class_list))

# %%
import matplotlib.cm as cmx
import matplotlib.colors as colors
#set the position
pos=nx.spring_layout(G)
#set a value map to the class dictionary created above
val_map = class_dict
#set the color legend to equal the legend dictionary
color_legend = legend_dictionary
values = [val_map.get(node, 0) for node in G.nodes()]
#color mapping
cool = cm = plt.get_cmap('cool')
cNorm  = colors.Normalize(vmin=0, vmax=max(values))
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=cool)

#use a f, ax plot to call the plot as a parameter and ax to build a legend
plt.figure(figsize=(15,12))
f = plt.figure(1)
ax = f.add_subplot(1,1,1)
for label in color_legend:
    ax.plot([0],[0],color=scalarMap.to_rgba(color_legend[label]), label=label, marker='o', linewidth=0)

#draw the network map with colored nodes and legend
multi_G = nx.draw_networkx(G,pos, cmap=cool, vmin=0, vmax=max(values), node_color=values, with_labels=False, ax=ax,
                node_size=75, alpha=0.8)

# Setting it to how it was looking before.                                                                                                              
plt.axis('off')
f.set_facecolor('w')

plt.title('E. Coli Operon-Transcription Factor Network by Regulator Class')
plt.legend()

plt.show()

# %% [markdown]
# ## Visual Analysis of Network Map Part 2
#
# Now that our network map is color coded, futher information can be gleened. We see that the node with the highest degree is indeed an activator. Perhaps the most interesting feature of this map are the smaller, external clusters. The majority of the small clusters are comprised of only one type of activator class. This an create what is known as a feedback loop. There are two types of feedback loops, positive and negative. In a positive feedback loop an increase in A causes an increase in B, and that increase in B induces a further increase in A, and so on and so forth. An example of this can be found in blood clotting. When you have a cut, a chemical is released into the body that triggers the activation of platlets. Once activated, these platlets release more of this chemical and activate even more platlets. This continues until the wound is clotted. A negative feedback loop, as you could guess, is the reverse of this. We can see the utilization of genetic feedback loops in a few of the external clusters.
#
# The node with the highest degree was node 66 in our list. This node is the CRP gene, which controls the production of cAMP, the building block of ATP. ATP, if you remember your cellular biology, is the primary energy source for all cells. So without cAMP, you don't have ATP and your cell dies. It is the central feature of all cellular metabolism. It therefore makes sense that this gene is connected to all the other vital features and genes in the cell. Below is a list of all of the neighbors connected to this node.

# %%
#list out all the neighbors of the node with the largest degree, 66
node66 = list(nx.all_neighbors(G, 66))

for node in node66:
    print(str(node) + ':', G.node[node])
# Out:
# 5: {'Gene': 'acs', 'Regulation Type': 'activator', 'Transcription Factor Name': 'AdiY', 'Operon Name': 'adiA'}
# 13: {'Gene': 'aldB', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'aceBAK'}
# 16: {'Gene': 'ansB', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'betIBA'}
# 19: {'Gene': 'araBAD', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'dctA'}
# 20: {'Gene': 'araC', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'fadBA'}
# 21: {'Gene': 'araE', 'Regulation Type': 'activator', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'focA-pflB'}
# 22: {'Gene': 'araFG_araH_1H_2', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'fumA'}
# 23: {'Gene': 'araJ', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ArcA', 'Operon Name': 'fumC'}
# 56: {'Gene': 'caiF', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CpxR', 'Operon Name': 'dsbA'}
# 57: {'Gene': 'caiTABCDE', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CpxR', 'Operon Name': 'ecfI'}
# 60: {'Gene': 'cirA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CpxR', 'Operon Name': 'rotA'}
# 63: {'Gene': 'cpdB', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CpxR', 'Operon Name': 'xprB-dsbC-recJ'}
# 66: {'Gene': 'crp', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'ansB'}
# 72: {'Gene': 'cyaA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'caiF'}
# 83: {'Gene': 'dadAX', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'ebgAC'}
# 85: {'Gene': 'dctA', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'CRP', 'Operon Name': 'fadL'}
# 86: {'Gene': 'dcuB_fumB', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'fixABCX'}
# 87: {'Gene': 'deoCABD', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'flhDC'}
# 95: {'Gene': 'dsdXA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'glgS'}
# 96: {'Gene': 'ebgAC', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'glnALG'}
# 112: {'Gene': 'epd_pgk', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'manXYZ'}
# 118: {'Gene': 'fadL', 'Regulation Type': 'dual', 'Transcription Factor Name': 'CRP', 'Operon Name': 'nupG'}
# 129: {'Gene': 'fixABCX', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'tdcABCDEFG'}
# 136: {'Gene': 'flhDC', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CRP', 'Operon Name': 'yiaKLMNOPQRS'}
# 144: {'Gene': 'focA_pflB', 'Regulation Type': 'activator', 'Transcription Factor Name': 'CysB', 'Operon Name': 'cysDNC'}
# 150: {'Gene': 'fucAO', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'CytR', 'Operon Name': 'nupC'}
# 151: {'Gene': 'fucPIKUR', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'CytR', 'Operon Name': 'nupG'}
# 154: {'Gene': 'fur', 'Regulation Type': 'dual', 'Transcription Factor Name': 'CytR', 'Operon Name': 'tsx'}
# 155: {'Gene': 'galETKM', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'CytR', 'Operon Name': 'udp'}
# 157: {'Gene': 'galS', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'DcuR', 'Operon Name': 'dcuB-fumB'}
# 166: {'Gene': 'glgCAP', 'Regulation Type': 'activator', 'Transcription Factor Name': 'EbgR', 'Operon Name': 'ebgAC'}
# 167: {'Gene': 'glgS', 'Regulation Type': 'activator', 'Transcription Factor Name': 'EmrR', 'Operon Name': 'emrRAB'}
# 169: {'Gene': 'glnALG', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'EnvY', 'Operon Name': 'ompF'}
# 172: {'Gene': 'glpACB', 'Regulation Type': 'activator', 'Transcription Factor Name': 'ExuR', 'Operon Name': 'exuT'}
# 173: {'Gene': 'glpD', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ExuR', 'Operon Name': 'uxaCA'}
# 174: {'Gene': 'glpFK', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'ExuR', 'Operon Name': 'uxuABR'}
# 176: {'Gene': 'glpTQ', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FadR', 'Operon Name': 'fadBA'}
# 177: {'Gene': 'gltA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FadR', 'Operon Name': 'fadL'}
# 180: {'Gene': 'gntKU', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FecI', 'Operon Name': 'fecABCDE'}
# 182: {'Gene': 'gntT', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FhlA', 'Operon Name': 'fdhF'}
# 209: {'Gene': 'ivbL_ilvBN', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FIS', 'Operon Name': 'tyrTV'}
# 216: {'Gene': 'lacZYA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FlhDC', 'Operon Name': 'fliE'}
# 232: {'Gene': 'malEFG', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FNR', 'Operon Name': 'acs'}
# 233: {'Gene': 'malI', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FNR', 'Operon Name': 'ansB'}
# 234: {'Gene': 'malK_lamB_malM', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'Fnr', 'Operon Name': 'arcA'}
# 236: {'Gene': 'malS', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FNR', 'Operon Name': 'caiF'}
# 237: {'Gene': 'malT', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FNR', 'Operon Name': 'cydAB'}
# 238: {'Gene': 'malXY', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FNR', 'Operon Name': 'cyoABCDE'}
# 240: {'Gene': 'manXYZ', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FNR', 'Operon Name': 'dmsABC'}
# 245: {'Gene': 'melAB', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FNR', 'Operon Name': 'glpACB'}
# 246: {'Gene': 'melR', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'FNR', 'Operon Name': 'hypABCDE'}
# 255: {'Gene': 'mglBAC', 'Regulation Type': 'activator', 'Transcription Factor Name': 'FruR', 'Operon Name': 'aceBAK'}
# 270: {'Gene': 'nagBACD', 'Regulation Type': 'activator', 'Transcription Factor Name': 'Fur', 'Operon Name': 'fhuACDB'}
# 271: {'Gene': 'nagE', 'Regulation Type': 'activator', 'Transcription Factor Name': 'Fur', 'Operon Name': 'fur'}
# 287: {'Gene': 'nupG', 'Regulation Type': 'activator', 'Transcription Factor Name': 'GntR', 'Operon Name': 'edd-eda'}
# 289: {'Gene': 'ompA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'GntR', 'Operon Name': 'gntT'}
# 308: {'Gene': 'ppiA', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'IHF', 'Operon Name': 'aceBAK'}
# 312: {'Gene': 'proP', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'IHF', 'Operon Name': 'ecpD-htrE'}
# 318: {'Gene': 'ptsHI_crr', 'Regulation Type': 'activator', 'Transcription Factor Name': 'IHF', 'Operon Name': 'hycABCDEFGH'}
# 336: {'Gene': 'rhaBAD', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'LexA', 'Operon Name': 'polB'}
# 338: {'Gene': 'rhaT', 'Regulation Type': 'activator', 'Transcription Factor Name': 'LexA', 'Operon Name': 'recN'}
# 345: {'Gene': 'rpoH', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'LexA', 'Operon Name': 'uvrC'}
# 351: {'Gene': 'sdhCDAB_b0725_sucABCD', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'Lrp', 'Operon Name': 'livJ'}
# 361: {'Gene': 'speC', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'Lrp', 'Operon Name': 'stpA'}
# 362: {'Gene': 'srlAEBD_gutM_srlR_gutQ', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'LysR', 'Operon Name': 'lysA'}
# 369: {'Gene': 'tdcABCDEFG', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'MalT', 'Operon Name': 'malPQ'}
# 373: {'Gene': 'tnaLAB', 'Regulation Type': 'dual', 'Transcription Factor Name': 'MarA', 'Operon Name': 'fumC'}
# 382: {'Gene': 'tsx', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'MetJ', 'Operon Name': 'metF'}
# 387: {'Gene': 'ubiG', 'Regulation Type': 'activator', 'Transcription Factor Name': 'MetR', 'Operon Name': 'metH'}
# 388: {'Gene': 'udp', 'Regulation Type': 'activator', 'Transcription Factor Name': 'MetR', 'Operon Name': 'metR'}
# 390: {'Gene': 'uhpT', 'Regulation Type': 'activator', 'Transcription Factor Name': 'Mlc', 'Operon Name': 'malT'}
# 414: {'Gene': 'yhfA', 'Regulation Type': 'activator', 'Transcription Factor Name': 'NarL', 'Operon Name': 'narK'}
# 416: {'Gene': 'yiaKLMNOPQRS', 'Regulation Type': 'repressor', 'Transcription Factor Name': 'NarL', 'Operon Name': 'nrfABCDEFG'}

# %% [markdown]
# ## Network Maps by Class
#
# We can also view how each TF class are intraconnected by only looking at connections for that particular class. Below are all the maps created for each unique class. The activator network, which has the primary central node resembles the complete network map. Without that large central node, the repressor and dual maps look far more sporatic and separated.
#
# The final graph uses the PyVis package to create a unqiue view of our network. This package is still in its infancy, but with added features it shows great promise.

# %%
#create dataframes containing unique TF classes
activator = df[df['regulation_type'] == 'activator']
repressor = df[df['regulation_type'] == 'repressor']
dual = df[df['regulation_type'] == 'dual']

tuple_a = [(x[4], x[5]) for x in activator.values]
tuple_r = [(x[4], x[5]) for x in repressor.values]
tuple_d = [(x[4], x[5]) for x in dual.values]

G1 = nx.Graph()
G2 = nx.Graph()
G3 = nx.Graph()

G1.add_edges_from(tuple_a)
G2.add_edges_from(tuple_r)
G3.add_edges_from(tuple_d)

# %%
#draw the activator network graph
plt.figure(figsize=(15, 12))
nx.draw_networkx(G1,
                 pos=nx.spring_layout(G1), 
                 node_color='chartreuse',
                 edge_color='black',
                 node_size=75,
                 with_labels=False,
                 alpha=.7
                 )
plt.title('Activator Factor Network')
plt.axis('off')
plt.show()

# %%
#draw the repressor network graph
plt.figure(figsize=(15, 12))
nx.draw_networkx(G2,
                 pos=nx.spring_layout(G2), 
                 node_color='turquoise',
                 edge_color='black',
                 node_size=75,
                 with_labels=False,
                 alpha=.7
                 )
plt.title('Repressor Factor Network')
plt.axis('off')
plt.show()

# %%
#draw the repressor network graph
plt.figure(figsize=(15, 12))
nx.draw_networkx(G3,
                 pos=nx.spring_layout(G3), 
                 node_color='magenta',
                 edge_color='black',
                 node_size=75,
                 with_labels=False,
                 alpha=.7
                 )
plt.title('Dual Factor Network')
plt.axis('off')
plt.show()

# %%
from pyvis import network as net

gnet = net.Network(notebook=True, bgcolor='#222222', font_color='white', width='700px', height='700px')
gnet.barnes_hut()

gnet.from_nx(G)
neighbor_map = gnet.get_adj_list()

for node in df['id']:
    if node in gnet.nodes:
        gnet.node[node]['Gene'] = df.loc[df['id']==node,'gene'].values[0]
        gnet.node[node]['Regulation Type'] = df.loc[df['id']==node,'regulation_type'].values[0]
        gnet.node[node]['Transcription Factor Name'] = df.loc[df['id']==node,'transcripion_name'].values[0]
        gnet.node[node]['Operon Name'] = df.loc[df['id']==node,'operon_name'].values[0]

gnet.show('genes.html')
# Out:
#         <iframe
#             width="700px"
#             height="700px"
#             src="genes.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
